# %% [markdown]
# <a href="https://colab.research.google.com/github/saeed2016/learnbasic/blob/master/Copy_of_YOLOv5_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu102 (CPU)

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           file.jpg  # image
#                           file.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/NUsoVlDFqZg'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !unzip -q ../sheeps.mp4.zip -d ../

# %%
# !unzip -q /content/train_data.zip -d ../

# %%
# %rm -rf runs
#!python detect.py --weights /content/last.pt --img 640 --conf 0.49 --source /content/Untitled.png
#Image(filename='runs/detect/exp/zidane.jpg', width=600)
# !python detect.py --weights /content/last.pt  --conf 0.49 --source /content/20210824_11-53-00-20210824_11-54-29.mp4
# Out:
# detect: weights=['/content/last.pt'], source=/content/20210824_11-53-00-20210824_11-54-29.mp4, imgsz=[640, 640], conf_thres=0.49, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-380-g11f85e7 torch 1.9.0+cu102 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.293s)
# video 1/1 (2/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (3/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (4/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (5/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (6/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (7/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (8/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (9/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.287s)
# video 1/1 (10/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.283s)
# video 1/1 (11/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (12/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.286s)
# video 1/1 (13/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (14/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (15/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (16/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (17/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.266s)
# video 1/1 (18/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.283s)
# video 1/1 (19/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (20/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (21/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (22/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (23/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (24/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (25/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (26/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (27/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (28/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.266s)
# video 1/1 (29/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (30/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.302s)
# video 1/1 (31/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (32/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (33/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (34/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (35/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (36/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (37/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (38/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (39/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (40/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (41/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (42/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (43/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (44/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (45/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (46/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (47/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (48/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.267s)
# video 1/1 (49/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (50/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (51/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (52/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (53/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (54/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (55/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (56/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (57/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (58/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (59/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (60/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (61/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (62/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.267s)
# video 1/1 (63/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (64/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (65/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (66/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (67/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (68/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.265s)
# video 1/1 (69/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (70/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (71/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.286s)
# video 1/1 (72/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (73/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (74/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (75/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (76/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (77/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.293s)
# video 1/1 (78/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (79/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (80/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (81/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (82/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (83/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (84/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (85/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.291s)
# video 1/1 (86/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (87/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (88/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (89/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (90/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.289s)
# video 1/1 (91/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (92/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (93/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (94/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (95/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (96/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (97/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.291s)
# video 1/1 (98/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (99/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (100/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (101/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (102/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (103/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (104/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (105/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (106/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (107/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (108/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (109/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (110/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (111/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (112/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.288s)
# video 1/1 (113/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (114/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (115/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (116/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (117/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (118/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (119/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (120/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (121/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (122/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (123/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (124/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (125/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (126/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (127/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (128/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (129/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (130/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (131/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.283s)
# video 1/1 (132/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (133/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (134/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.287s)
# video 1/1 (135/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (136/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (137/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.283s)
# video 1/1 (138/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.267s)
# video 1/1 (139/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (140/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.266s)
# video 1/1 (141/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (142/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.285s)
# video 1/1 (143/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (144/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (145/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (146/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (147/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (148/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (149/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.290s)
# video 1/1 (150/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (151/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (152/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (153/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (154/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (155/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (156/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (157/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (158/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (159/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (160/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (161/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (162/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (163/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (164/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (165/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (166/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (167/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.296s)
# video 1/1 (168/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (169/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (170/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.285s)
# video 1/1 (171/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (172/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (173/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (174/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (175/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (176/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (177/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.267s)
# video 1/1 (178/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (179/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (180/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (181/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.291s)
# video 1/1 (182/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (183/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (184/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (185/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (186/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (187/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (188/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (189/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (190/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (191/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (192/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (193/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (194/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (195/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (196/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (197/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (198/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (199/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (200/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (201/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (202/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (203/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (204/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (205/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (206/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (207/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.267s)
# video 1/1 (208/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (209/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (210/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (211/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (212/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (213/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (214/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (215/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (216/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (217/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (218/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (219/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (220/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (221/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (222/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (223/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (224/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (225/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (226/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (227/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (228/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (229/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (230/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.286s)
# video 1/1 (231/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (232/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (233/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (234/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (235/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (236/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.286s)
# video 1/1 (237/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (238/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (239/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (240/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.285s)
# video 1/1 (241/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (242/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (243/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.287s)
# video 1/1 (244/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (245/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (246/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (247/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (248/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (249/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.292s)
# video 1/1 (250/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (251/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (252/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.299s)
# video 1/1 (253/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (254/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.295s)
# video 1/1 (255/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.302s)
# video 1/1 (256/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.283s)
# video 1/1 (257/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (258/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (259/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (260/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.283s)
# video 1/1 (261/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (262/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (263/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (264/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (265/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (266/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.301s)
# video 1/1 (267/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (268/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (269/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (270/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (271/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (272/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.287s)
# video 1/1 (273/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.288s)
# video 1/1 (274/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (275/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (276/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (277/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (278/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (279/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (280/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (281/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (282/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.267s)
# video 1/1 (283/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.267s)
# video 1/1 (284/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (285/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (286/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (287/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (288/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (289/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (290/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (291/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (292/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (293/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (294/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (295/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (296/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (297/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (298/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.269s)
# video 1/1 (299/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (300/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (301/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (302/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (303/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (304/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (305/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.292s)
# video 1/1 (306/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.266s)
# video 1/1 (307/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (308/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.285s)
# video 1/1 (309/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.272s)
# video 1/1 (310/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (311/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (312/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (313/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (314/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (315/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (316/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (317/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (318/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (319/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (320/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (321/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (322/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (323/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.270s)
# video 1/1 (324/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.268s)
# video 1/1 (325/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (326/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (327/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.285s)
# video 1/1 (328/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.274s)
# video 1/1 (329/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (330/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.278s)
# video 1/1 (331/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (332/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.273s)
# video 1/1 (333/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.282s)
# video 1/1 (334/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (335/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.271s)
# video 1/1 (336/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.279s)
# video 1/1 (337/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (338/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (339/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.280s)
# video 1/1 (340/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (341/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.277s)
# video 1/1 (342/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.275s)
# video 1/1 (343/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.281s)
# video 1/1 (344/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)
# video 1/1 (345/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.284s)
# video 1/1 (346/2934) /content/20210824_11-53-00-20210824_11-54-29.mp4: number of detection: 0
# 384x640 Done. (0.276s)

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# Run YOLOv5x on COCO val2017
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=./data/coco.yaml, weights=['yolov5x.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True
# YOLOv5 🚀 v5.0-367-g01cdb76 torch 1.9.0+cu102 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5x.pt to yolov5x.pt...
# 100% 168M/168M [00:08<00:00, 20.6MB/s]
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients
# val: Scanning '../datasets/coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 2749.96it/s]
# val: New cache created: ../datasets/coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [01:08<00:00,  2.28it/s]
#                  all       5000      36335      0.746      0.626       0.68       0.49
# Speed: 0.1ms pre-process, 5.1ms inference, 1.6ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.94s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=83.60s).
# Accumulating evaluation results...
# DONE (t=13.22s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.546
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ../coco/images  # move to /coco

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python val.py --weights yolov5s.pt --data coco128_custom.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 4 --epochs 200 --data coco128_custom.yaml --weights yolov5s.pt --save 0 --cache

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img align="left" src="https://user-images.githubusercontent.com/26833433/125274843-a27bc600-e30e-11eb-9a44-62af0b7a50a2.png" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note an Ultralytics **Mosaic Dataloader** is used for training (shown below), which combines 4 images into 1 mosaic during training.
#
# > <img src="https://user-images.githubusercontent.com/26833433/124931219-48bf8700-e002-11eb-84f0-e05d95b118dd.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/124931217-4826f080-e002-11eb-87b9-ae0925a8c94b.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/124931209-46f5c380-e002-11eb-9bd5-7a3de2be9851.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_
#
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) as `results.csv`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.csv` file manually:
#
# ```python
# from utils.plots import plot_results
# plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
# ```
#
# <img align="left" width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/126906780-8c5e2990-6116-4de6-b78a-367244a33ccf.png">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.25 --iou 0.45  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
